# %%
import pandas as pd

# %%
df = pd.read_csv('Mem-Map.csv')
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#           Type             Start               End           # Pages  \
# 0    Available  0000000000000000  0000000000086FFF  0000000000000087
# 1      BS_Data  0000000000087000  0000000000087FFF  0000000000000001
# 2    Available  0000000000088000  000000000009EFFF  0000000000000017
# 3     Reserved  000000000009F000  000000000009FFFF  0000000000000001
# 4    Available  0000000000100000  000000002AB3FFFF  000000000002AA40
# 5      BS_Data  000000002AB40000  000000002ABBFFFF  0000000000000080
# 6    Available  000000002ABC0000  0000000036AD3FFF  000000000000BF14
# 7      BS_Data  0000000036AD4000  0000000036B22FFF  000000000000004F
# 8   LoaderCode  0000000036B23000  0000000036C39FFF  0000000000000117
# 9    Available  0000000036C3A000  0000000036C52FFF  0000000000000019
# 10     BS_Data  0000000036C53000  0000000036C69FFF  0000000000000017
# 11   Available  0000000036C6A000  0000000036C6AFFF  0000000000000001
# 12     BS_Data  0000000036C6B000  000000003C8FEFFF  0000000000005C94
# ...

# %%
df = df.sort_values(by = 'Start')

# %%
df
# Out:
#           Type             Start               End           # Pages  \
# 0    Available  0000000000000000  0000000000086FFF  0000000000000087
# 1      BS_Data  0000000000087000  0000000000087FFF  0000000000000001
# 2    Available  0000000000088000  000000000009EFFF  0000000000000017
# 3     Reserved  000000000009F000  000000000009FFFF  0000000000000001
# 66    Reserved  00000000000A0000  00000000000FFFFF  0000000000000060
# 4    Available  0000000000100000  000000002AB3FFFF  000000000002AA40
# 5      BS_Data  000000002AB40000  000000002ABBFFFF  0000000000000080
# 6    Available  000000002ABC0000  0000000036AD3FFF  000000000000BF14
# 7      BS_Data  0000000036AD4000  0000000036B22FFF  000000000000004F
# 8   LoaderCode  0000000036B23000  0000000036C39FFF  0000000000000117
# 9    Available  0000000036C3A000  0000000036C52FFF  0000000000000019
# 10     BS_Data  0000000036C53000  0000000036C69FFF  0000000000000017
# 11   Available  0000000036C6A000  0000000036C6AFFF  0000000000000001
# ...

# %%
df.to_csv('Mem-Map-Asc.csv', index = False)
